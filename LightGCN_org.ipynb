# %%
# !git clone https://github.com/gusye1234/LightGCN-PyTorch.git
# Out:
# Cloning into 'LightGCN-PyTorch'...
# remote: Enumerating objects: 544, done.
# remote: Counting objects: 100% (539/539), done.
# remote: Compressing objects: 100% (205/205), done.
# remote: Total 544 (delta 325), reused 518 (delta 314), pack-reused 5
# Receiving objects: 100% (544/544), 81.84 MiB | 13.55 MiB/s, done.
# Resolving deltas: 100% (325/325), done.

# %%
# !pip install torch==1.4.0
# !pip install pandas==0.24.2
# !pip install scipy==1.3.0
# !pip install numpy==1.22.0
# !pip install tensorboardX==1.8
# !pip install scikit-learn==0.23.2
# !pip install tqdm==4.48.2
# Out:
# Collecting tensorboardX==1.8
#   Downloading tensorboardX-1.8-py2.py3-none-any.whl (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.3/216.3 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tensorboardX==1.8) (1.25.2)
# Requirement already satisfied: protobuf>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorboardX==1.8) (3.20.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from tensorboardX==1.8) (1.16.0)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-1.8

# %%
# !pwd
# Out:
# /content

# %%
 # %cd LightGCN-PyTorch/code
# Out:
# /content/LightGCN-PyTorch/code

# %%
# !pwd
# Out:
# /content/LightGCN-PyTorch/code

# %%
# !python /content/LightGCN-PyTorch/code/main.py --decay=1e-4 --lr=0.001 --layer=3 --seed=2020 --dataset="gowalla" --topks="[20]" --recdim=64
# Out:
# Cpp extension not loaded
# >>SEED: 2020
# loading [../data/gowalla]
# 810128 interactions for training
# 217242 interactions for testing
# gowalla Sparsity : 0.0008396216228570436
# gowalla is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 64,
#  'lightGCN_n_layers': 3,
#  'lr': 0.001,
#  'multicore': 0,
#  'pretrain': 0,
#  'test_u_batch_size': 100}
# cores for test: 1
# comment: lgn
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# use NORMAL distribution initilizer
# loading adjacency matrix
# successfully loaded...
# /content/LightGCN-PyTorch/code/dataloader.py:330: UserWarning: torch.sparse.SparseTensor(indices, values, shape, *, device=) is deprecated.  Please use torch.sparse_coo_tensor(indices, values, shape, dtype=, device=). (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:618.)
#   return torch.sparse.FloatTensor(index, data, torch.Size(coo.shape))
# don't split the matrix
# lgn is already to go(dropout:0)
# load and save to /content/LightGCN-PyTorch/code/checkpoints/lgn-gowalla-3-64.pth.tar
# [TEST]
# {'precision': array([0.00018755]), 'recall': array([0.00053749]), 'ndcg': array([0.00040836])}
# EPOCH[1/1000] loss0.545-|Sample:10.92|
# EPOCH[2/1000] loss0.240-|Sample:10.14|
# EPOCH[3/1000] loss0.163-|Sample:11.07|
# EPOCH[4/1000] loss0.131-|Sample:10.46|
# EPOCH[5/1000] loss0.112-|Sample:10.14|
# EPOCH[6/1000] loss0.099-|Sample:10.01|
# EPOCH[7/1000] loss0.090-|Sample:10.14|
# EPOCH[8/1000] loss0.084-|Sample:10.46|
# EPOCH[9/1000] loss0.078-|Sample:9.90|
# EPOCH[10/1000] loss0.074-|Sample:9.95|
# [TEST]
# {'precision': array([0.03665852]), 'recall': array([0.12015337]), 'ndcg': array([0.10059574])}
# EPOCH[11/1000] loss0.071-|Sample:10.08|
# EPOCH[12/1000] loss0.068-|Sample:10.09|
# EPOCH[13/1000] loss0.065-|Sample:10.14|
# EPOCH[14/1000] loss0.064-|Sample:9.53|
# EPOCH[15/1000] loss0.061-|Sample:9.96|
# EPOCH[16/1000] loss0.059-|Sample:9.47|
# EPOCH[17/1000] loss0.057-|Sample:9.87|
# EPOCH[18/1000] loss0.055-|Sample:9.23|
# EPOCH[19/1000] loss0.054-|Sample:9.83|
# EPOCH[20/1000] loss0.052-|Sample:9.88|
# [TEST]
# {'precision': array([0.03967613]), 'recall': array([0.13131503]), 'ndcg': array([0.10875967])}
# EPOCH[21/1000] loss0.052-|Sample:9.71|
# EPOCH[22/1000] loss0.050-|Sample:9.53|
# EPOCH[23/1000] loss0.049-|Sample:9.97|
# EPOCH[24/1000] loss0.048-|Sample:9.89|
# EPOCH[25/1000] loss0.047-|Sample:9.24|
# EPOCH[26/1000] loss0.046-|Sample:9.85|
# EPOCH[27/1000] loss0.045-|Sample:9.69|
# EPOCH[28/1000] loss0.044-|Sample:9.96|
# EPOCH[29/1000] loss0.043-|Sample:9.78|
# EPOCH[30/1000] loss0.042-|Sample:9.57|
# [TEST]
# {'precision': array([0.04200717]), 'recall': array([0.13924743]), 'ndcg': array([0.11538367])}
# EPOCH[31/1000] loss0.042-|Sample:9.71|
# EPOCH[32/1000] loss0.041-|Sample:9.59|
# EPOCH[33/1000] loss0.040-|Sample:9.48|
# EPOCH[34/1000] loss0.039-|Sample:9.79|
# EPOCH[35/1000] loss0.039-|Sample:9.91|
# EPOCH[36/1000] loss0.038-|Sample:9.24|
# EPOCH[37/1000] loss0.037-|Sample:9.34|
# EPOCH[38/1000] loss0.037-|Sample:9.89|
# EPOCH[39/1000] loss0.036-|Sample:10.02|
# EPOCH[40/1000] loss0.036-|Sample:9.76|
# [TEST]
# {'precision': array([0.0435076]), 'recall': array([0.14442291]), 'ndcg': array([0.12018409])}
# EPOCH[41/1000] loss0.035-|Sample:9.81|
# EPOCH[42/1000] loss0.035-|Sample:9.78|
# EPOCH[43/1000] loss0.034-|Sample:9.70|
# EPOCH[44/1000] loss0.034-|Sample:9.81|
# EPOCH[45/1000] loss0.033-|Sample:9.71|
# EPOCH[46/1000] loss0.033-|Sample:9.39|
# EPOCH[47/1000] loss0.032-|Sample:9.93|
# EPOCH[48/1000] loss0.032-|Sample:9.61|
# EPOCH[49/1000] loss0.032-|Sample:9.90|
# EPOCH[50/1000] loss0.031-|Sample:9.59|
# [TEST]
# {'precision': array([0.04473675]), 'recall': array([0.14866195]), 'ndcg': array([0.12404281])}
# EPOCH[51/1000] loss0.031-|Sample:9.79|
# EPOCH[52/1000] loss0.030-|Sample:9.85|
# EPOCH[53/1000] loss0.030-|Sample:9.69|
# EPOCH[54/1000] loss0.030-|Sample:8.95|
# EPOCH[55/1000] loss0.030-|Sample:9.38|
# EPOCH[56/1000] loss0.029-|Sample:9.41|
# EPOCH[57/1000] loss0.030-|Sample:9.47|
# EPOCH[58/1000] loss0.028-|Sample:9.87|
# EPOCH[59/1000] loss0.029-|Sample:9.58|
# EPOCH[60/1000] loss0.028-|Sample:9.62|
# [TEST]
# {'precision': array([0.04582691]), 'recall': array([0.15269575]), 'ndcg': array([0.12770019])}
# EPOCH[61/1000] loss0.028-|Sample:9.74|
# EPOCH[62/1000] loss0.028-|Sample:9.52|
# EPOCH[63/1000] loss0.027-|Sample:9.81|
# EPOCH[64/1000] loss0.027-|Sample:9.66|
# EPOCH[65/1000] loss0.027-|Sample:9.04|
# EPOCH[66/1000] loss0.027-|Sample:9.55|
# EPOCH[67/1000] loss0.026-|Sample:9.14|
# EPOCH[68/1000] loss0.026-|Sample:9.42|
# EPOCH[69/1000] loss0.026-|Sample:9.97|
# EPOCH[70/1000] loss0.026-|Sample:9.59|
# [TEST]
# {'precision': array([0.04667091]), 'recall': array([0.15541536]), 'ndcg': array([0.13018555])}
# EPOCH[71/1000] loss0.026-|Sample:9.78|
# EPOCH[72/1000] loss0.025-|Sample:9.73|
# EPOCH[73/1000] loss0.025-|Sample:9.60|
# EPOCH[74/1000] loss0.025-|Sample:9.98|
# EPOCH[75/1000] loss0.024-|Sample:9.72|
# EPOCH[76/1000] loss0.024-|Sample:9.45|
# EPOCH[77/1000] loss0.024-|Sample:9.85|
# EPOCH[78/1000] loss0.023-|Sample:9.72|
# EPOCH[79/1000] loss0.023-|Sample:9.39|
# EPOCH[80/1000] loss0.023-|Sample:9.68|
# [TEST]
# {'precision': array([0.04764887]), 'recall': array([0.15883861]), 'ndcg': array([0.13281343])}
# EPOCH[81/1000] loss0.023-|Sample:9.66|
# EPOCH[82/1000] loss0.023-|Sample:9.12|
# EPOCH[83/1000] loss0.023-|Sample:9.88|
# EPOCH[84/1000] loss0.023-|Sample:9.83|
# EPOCH[85/1000] loss0.023-|Sample:9.66|
# EPOCH[86/1000] loss0.022-|Sample:9.69|
# EPOCH[87/1000] loss0.022-|Sample:9.56|
# EPOCH[88/1000] loss0.022-|Sample:9.85|
# EPOCH[89/1000] loss0.022-|Sample:9.66|
# EPOCH[90/1000] loss0.022-|Sample:9.17|
# [TEST]
# {'precision': array([0.04828354]), 'recall': array([0.16123923]), 'ndcg': array([0.13488293])}
# EPOCH[91/1000] loss0.022-|Sample:9.48|
# EPOCH[92/1000] loss0.021-|Sample:9.67|
# EPOCH[93/1000] loss0.021-|Sample:9.27|
# EPOCH[94/1000] loss0.021-|Sample:9.35|
# EPOCH[95/1000] loss0.021-|Sample:9.61|
# EPOCH[96/1000] loss0.021-|Sample:9.86|
# EPOCH[97/1000] loss0.021-|Sample:9.61|
# EPOCH[98/1000] loss0.021-|Sample:9.21|
# EPOCH[99/1000] loss0.021-|Sample:9.20|
# EPOCH[100/1000] loss0.021-|Sample:9.80|
# [TEST]
# {'precision': array([0.04904046]), 'recall': array([0.16339769]), 'ndcg': array([0.13709397])}
# EPOCH[101/1000] loss0.020-|Sample:9.80|
# EPOCH[102/1000] loss0.020-|Sample:9.57|
# EPOCH[103/1000] loss0.020-|Sample:9.78|
# EPOCH[104/1000] loss0.020-|Sample:10.24|
# EPOCH[105/1000] loss0.020-|Sample:9.23|
# EPOCH[106/1000] loss0.020-|Sample:9.74|
# EPOCH[107/1000] loss0.020-|Sample:9.64|
# EPOCH[108/1000] loss0.019-|Sample:9.73|
# EPOCH[109/1000] loss0.019-|Sample:9.63|
# EPOCH[110/1000] loss0.019-|Sample:9.52|
# [TEST]
# {'precision': array([0.04967011]), 'recall': array([0.16563994]), 'ndcg': array([0.13883127])}
# EPOCH[111/1000] loss0.019-|Sample:9.54|
# EPOCH[112/1000] loss0.019-|Sample:9.80|
# EPOCH[113/1000] loss0.019-|Sample:9.45|
# EPOCH[114/1000] loss0.019-|Sample:9.78|
# EPOCH[115/1000] loss0.019-|Sample:9.51|
# EPOCH[116/1000] loss0.019-|Sample:9.53|
# EPOCH[117/1000] loss0.019-|Sample:9.72|
# EPOCH[118/1000] loss0.018-|Sample:9.36|
# EPOCH[119/1000] loss0.018-|Sample:9.69|
# EPOCH[120/1000] loss0.018-|Sample:9.60|
# [TEST]
# {'precision': array([0.05003014]), 'recall': array([0.16645654]), 'ndcg': array([0.14008069])}
# EPOCH[121/1000] loss0.018-|Sample:9.42|
# EPOCH[122/1000] loss0.018-|Sample:9.68|
# EPOCH[123/1000] loss0.018-|Sample:9.51|
# EPOCH[124/1000] loss0.018-|Sample:9.87|
# EPOCH[125/1000] loss0.018-|Sample:9.68|
# EPOCH[126/1000] loss0.018-|Sample:9.87|
# EPOCH[127/1000] loss0.018-|Sample:9.65|
# EPOCH[128/1000] loss0.018-|Sample:9.26|
# EPOCH[129/1000] loss0.018-|Sample:9.49|
# EPOCH[130/1000] loss0.018-|Sample:9.65|
# [TEST]
# {'precision': array([0.05057606]), 'recall': array([0.16803698]), 'ndcg': array([0.14162368])}
# EPOCH[131/1000] loss0.017-|Sample:9.41|
# EPOCH[132/1000] loss0.017-|Sample:12.82|
# EPOCH[133/1000] loss0.017-|Sample:9.96|
# EPOCH[134/1000] loss0.017-|Sample:9.76|
# EPOCH[135/1000] loss0.017-|Sample:9.62|
# EPOCH[136/1000] loss0.017-|Sample:9.70|
# EPOCH[137/1000] loss0.017-|Sample:9.80|
# EPOCH[138/1000] loss0.017-|Sample:9.66|
# EPOCH[139/1000] loss0.017-|Sample:9.77|
# EPOCH[140/1000] loss0.017-|Sample:9.64|
# [TEST]
# {'precision': array([0.05098131]), 'recall': array([0.16939592]), 'ndcg': array([0.14267914])}
# EPOCH[141/1000] loss0.017-|Sample:9.75|
# EPOCH[142/1000] loss0.017-|Sample:9.64|
# EPOCH[143/1000] loss0.017-|Sample:9.68|
# EPOCH[144/1000] loss0.017-|Sample:9.70|
# EPOCH[145/1000] loss0.017-|Sample:9.66|
# EPOCH[146/1000] loss0.016-|Sample:9.75|
# EPOCH[147/1000] loss0.016-|Sample:9.63|
# EPOCH[148/1000] loss0.016-|Sample:9.96|
# EPOCH[149/1000] loss0.016-|Sample:9.59|
# EPOCH[150/1000] loss0.016-|Sample:9.57|
# [TEST]
# {'precision': array([0.05128274]), 'recall': array([0.17043011]), 'ndcg': array([0.14369758])}
# EPOCH[151/1000] loss0.016-|Sample:9.82|
# EPOCH[152/1000] loss0.016-|Sample:9.79|
# EPOCH[153/1000] loss0.016-|Sample:9.91|
# EPOCH[154/1000] loss0.016-|Sample:9.69|
# EPOCH[155/1000] loss0.016-|Sample:9.51|
# EPOCH[156/1000] loss0.016-|Sample:9.69|
# EPOCH[157/1000] loss0.016-|Sample:9.61|
# EPOCH[158/1000] loss0.016-|Sample:9.34|
# EPOCH[159/1000] loss0.016-|Sample:9.66|
# EPOCH[160/1000] loss0.016-|Sample:9.92|
# [TEST]
# {'precision': array([0.05161263]), 'recall': array([0.1715222]), 'ndcg': array([0.14475665])}
# EPOCH[161/1000] loss0.016-|Sample:10.16|
# EPOCH[162/1000] loss0.015-|Sample:9.77|
# EPOCH[163/1000] loss0.016-|Sample:9.98|
# EPOCH[164/1000] loss0.015-|Sample:9.92|
# EPOCH[165/1000] loss0.015-|Sample:9.49|
# EPOCH[166/1000] loss0.015-|Sample:9.62|
# EPOCH[167/1000] loss0.015-|Sample:8.98|
# EPOCH[168/1000] loss0.015-|Sample:9.99|
# EPOCH[169/1000] loss0.015-|Sample:9.68|
# EPOCH[170/1000] loss0.015-|Sample:9.64|
# [TEST]
# {'precision': array([0.05179014]), 'recall': array([0.17200728]), 'ndcg': array([0.14534748])}
# EPOCH[171/1000] loss0.015-|Sample:9.17|
# EPOCH[172/1000] loss0.015-|Sample:9.77|
# EPOCH[173/1000] loss0.015-|Sample:9.69|
# EPOCH[174/1000] loss0.015-|Sample:9.72|
# EPOCH[175/1000] loss0.015-|Sample:9.46|
# EPOCH[176/1000] loss0.015-|Sample:9.85|
# EPOCH[177/1000] loss0.015-|Sample:9.60|
# EPOCH[178/1000] loss0.015-|Sample:8.90|
# EPOCH[179/1000] loss0.015-|Sample:9.56|
# EPOCH[180/1000] loss0.015-|Sample:9.61|
# [TEST]
# {'precision': array([0.05202961]), 'recall': array([0.17248332]), 'ndcg': array([0.14587208])}
# EPOCH[181/1000] loss0.015-|Sample:9.36|
# EPOCH[182/1000] loss0.015-|Sample:9.20|
# EPOCH[183/1000] loss0.015-|Sample:9.75|
# EPOCH[184/1000] loss0.015-|Sample:9.69|
# EPOCH[185/1000] loss0.015-|Sample:9.56|
# EPOCH[186/1000] loss0.015-|Sample:9.32|
# EPOCH[187/1000] loss0.014-|Sample:9.63|
# EPOCH[188/1000] loss0.015-|Sample:9.73|
# EPOCH[189/1000] loss0.015-|Sample:9.67|
# EPOCH[190/1000] loss0.015-|Sample:9.76|
# [TEST]
# {'precision': array([0.05234778]), 'recall': array([0.17321316]), 'ndcg': array([0.14665503])}
# EPOCH[191/1000] loss0.015-|Sample:9.55|
# EPOCH[192/1000] loss0.014-|Sample:9.50|
# EPOCH[193/1000] loss0.015-|Sample:9.59|
# EPOCH[194/1000] loss0.014-|Sample:9.56|
# EPOCH[195/1000] loss0.014-|Sample:9.01|
# EPOCH[196/1000] loss0.014-|Sample:9.69|
# EPOCH[197/1000] loss0.014-|Sample:9.58|
# EPOCH[198/1000] loss0.014-|Sample:9.42|
# EPOCH[199/1000] loss0.014-|Sample:9.58|
# EPOCH[200/1000] loss0.014-|Sample:9.38|
# [TEST]
# {'precision': array([0.05258557]), 'recall': array([0.17428267]), 'ndcg': array([0.14727026])}
# EPOCH[201/1000] loss0.014-|Sample:9.25|
# EPOCH[202/1000] loss0.014-|Sample:9.40|
# EPOCH[203/1000] loss0.014-|Sample:9.87|
# EPOCH[204/1000] loss0.014-|Sample:9.61|
# EPOCH[205/1000] loss0.014-|Sample:9.64|
# EPOCH[206/1000] loss0.014-|Sample:9.69|
# EPOCH[207/1000] loss0.014-|Sample:9.74|
# EPOCH[208/1000] loss0.014-|Sample:9.87|
# EPOCH[209/1000] loss0.014-|Sample:9.15|
# EPOCH[210/1000] loss0.014-|Sample:9.57|
# [TEST]
# {'precision': array([0.05277313]), 'recall': array([0.17486576]), 'ndcg': array([0.14774159])}
# EPOCH[211/1000] loss0.014-|Sample:9.45|
# EPOCH[212/1000] loss0.014-|Sample:9.70|
# EPOCH[213/1000] loss0.014-|Sample:9.96|
# EPOCH[214/1000] loss0.014-|Sample:9.68|
# EPOCH[215/1000] loss0.014-|Sample:9.51|
# EPOCH[216/1000] loss0.014-|Sample:9.66|
# EPOCH[217/1000] loss0.014-|Sample:9.52|
# EPOCH[218/1000] loss0.014-|Sample:8.85|
# EPOCH[219/1000] loss0.014-|Sample:9.45|
# EPOCH[220/1000] loss0.014-|Sample:9.71|
# [TEST]
# {'precision': array([0.05284848]), 'recall': array([0.17483458]), 'ndcg': array([0.14819714])}
# EPOCH[221/1000] loss0.014-|Sample:9.72|
# EPOCH[222/1000] loss0.013-|Sample:9.67|
# EPOCH[223/1000] loss0.013-|Sample:9.64|
# EPOCH[224/1000] loss0.014-|Sample:9.58|
# EPOCH[225/1000] loss0.014-|Sample:9.52|
# EPOCH[226/1000] loss0.014-|Sample:9.74|
# EPOCH[227/1000] loss0.014-|Sample:9.38|
# EPOCH[228/1000] loss0.013-|Sample:9.42|
# EPOCH[229/1000] loss0.013-|Sample:9.10|
# EPOCH[230/1000] loss0.013-|Sample:9.60|
# [TEST]
# {'precision': array([0.05313484]), 'recall': array([0.17569493]), 'ndcg': array([0.14865747])}
# EPOCH[231/1000] loss0.013-|Sample:9.23|
# EPOCH[232/1000] loss0.014-|Sample:9.32|
# EPOCH[233/1000] loss0.013-|Sample:10.70|
# EPOCH[234/1000] loss0.013-|Sample:9.64|
# EPOCH[235/1000] loss0.013-|Sample:9.53|
# EPOCH[236/1000] loss0.013-|Sample:9.71|
# EPOCH[237/1000] loss0.013-|Sample:9.63|
# EPOCH[238/1000] loss0.013-|Sample:9.58|
# EPOCH[239/1000] loss0.013-|Sample:9.48|
# EPOCH[240/1000] loss0.013-|Sample:9.69|
# [TEST]
# {'precision': array([0.05305446]), 'recall': array([0.17542906]), 'ndcg': array([0.14852576])}
# EPOCH[241/1000] loss0.013-|Sample:9.79|
# EPOCH[242/1000] loss0.013-|Sample:9.65|
# EPOCH[243/1000] loss0.013-|Sample:9.79|
# EPOCH[244/1000] loss0.013-|Sample:9.71|
# EPOCH[245/1000] loss0.013-|Sample:9.39|
# EPOCH[246/1000] loss0.013-|Sample:9.73|
# EPOCH[247/1000] loss0.013-|Sample:9.54|
# EPOCH[248/1000] loss0.013-|Sample:9.64|
# EPOCH[249/1000] loss0.013-|Sample:9.54|
# EPOCH[250/1000] loss0.013-|Sample:9.64|
# [TEST]
# {'precision': array([0.0531968]), 'recall': array([0.17546172]), 'ndcg': array([0.14879667])}
# EPOCH[251/1000] loss0.013-|Sample:9.11|
# EPOCH[252/1000] loss0.013-|Sample:9.60|
# EPOCH[253/1000] loss0.013-|Sample:9.61|
# EPOCH[254/1000] loss0.013-|Sample:9.72|
# EPOCH[255/1000] loss0.013-|Sample:9.50|
# EPOCH[256/1000] loss0.013-|Sample:9.14|
# EPOCH[257/1000] loss0.013-|Sample:9.59|
# EPOCH[258/1000] loss0.013-|Sample:9.46|
# EPOCH[259/1000] loss0.013-|Sample:9.66|
# EPOCH[260/1000] loss0.013-|Sample:9.12|
# [TEST]
# {'precision': array([0.05343626]), 'recall': array([0.17622874]), 'ndcg': array([0.14931334])}
# EPOCH[261/1000] loss0.013-|Sample:9.55|
# EPOCH[262/1000] loss0.013-|Sample:9.49|
# EPOCH[263/1000] loss0.013-|Sample:9.73|
# EPOCH[264/1000] loss0.013-|Sample:9.26|
# EPOCH[265/1000] loss0.013-|Sample:9.20|
# EPOCH[266/1000] loss0.013-|Sample:9.60|
# EPOCH[267/1000] loss0.013-|Sample:9.61|
# EPOCH[268/1000] loss0.013-|Sample:9.80|
# EPOCH[269/1000] loss0.013-|Sample:9.56|
# EPOCH[270/1000] loss0.013-|Sample:9.44|
# [TEST]
# {'precision': array([0.05365731]), 'recall': array([0.17686527]), 'ndcg': array([0.14979331])}
# EPOCH[271/1000] loss0.013-|Sample:9.49|
# EPOCH[272/1000] loss0.013-|Sample:9.68|
# EPOCH[273/1000] loss0.013-|Sample:9.70|
# EPOCH[274/1000] loss0.013-|Sample:9.68|
# EPOCH[275/1000] loss0.013-|Sample:9.00|
# EPOCH[276/1000] loss0.013-|Sample:9.70|
# EPOCH[277/1000] loss0.013-|Sample:9.61|
# EPOCH[278/1000] loss0.013-|Sample:9.58|
# EPOCH[279/1000] loss0.013-|Sample:9.49|
# EPOCH[280/1000] loss0.012-|Sample:9.57|
# [TEST]
# {'precision': array([0.05374272]), 'recall': array([0.17722057]), 'ndcg': array([0.15000298])}
# EPOCH[281/1000] loss0.013-|Sample:9.60|
# EPOCH[282/1000] loss0.013-|Sample:9.60|
# EPOCH[283/1000] loss0.012-|Sample:9.60|
# EPOCH[284/1000] loss0.013-|Sample:9.70|
# EPOCH[285/1000] loss0.013-|Sample:9.59|
# EPOCH[286/1000] loss0.013-|Sample:9.73|
# EPOCH[287/1000] loss0.013-|Sample:9.52|
# EPOCH[288/1000] loss0.012-|Sample:9.56|
# EPOCH[289/1000] loss0.013-|Sample:9.57|
# EPOCH[290/1000] loss0.013-|Sample:9.16|
# [TEST]
# {'precision': array([0.05365899]), 'recall': array([0.1767449]), 'ndcg': array([0.15003051])}
# EPOCH[291/1000] loss0.012-|Sample:9.45|
# EPOCH[292/1000] loss0.012-|Sample:9.53|
# EPOCH[293/1000] loss0.013-|Sample:9.66|
# EPOCH[294/1000] loss0.012-|Sample:9.74|
# EPOCH[295/1000] loss0.013-|Sample:9.10|
# EPOCH[296/1000] loss0.012-|Sample:9.50|
# EPOCH[297/1000] loss0.012-|Sample:9.55|
# EPOCH[298/1000] loss0.012-|Sample:9.43|
# EPOCH[299/1000] loss0.012-|Sample:9.63|
# EPOCH[300/1000] loss0.012-|Sample:9.55|
# [TEST]
# {'precision': array([0.0538231]), 'recall': array([0.17753683]), 'ndcg': array([0.15055061])}
# EPOCH[301/1000] loss0.013-|Sample:9.72|
# EPOCH[302/1000] loss0.012-|Sample:9.53|
# EPOCH[303/1000] loss0.012-|Sample:9.69|
# EPOCH[304/1000] loss0.012-|Sample:9.28|
# EPOCH[305/1000] loss0.012-|Sample:9.19|
# EPOCH[306/1000] loss0.013-|Sample:9.26|
# EPOCH[307/1000] loss0.012-|Sample:9.53|
# EPOCH[308/1000] loss0.012-|Sample:9.77|
# EPOCH[309/1000] loss0.013-|Sample:9.47|
# EPOCH[310/1000] loss0.012-|Sample:11.08|
# [TEST]
# {'precision': array([0.05384821]), 'recall': array([0.17756937]), 'ndcg': array([0.15072542])}
# EPOCH[311/1000] loss0.012-|Sample:9.33|
# EPOCH[312/1000] loss0.012-|Sample:9.62|
# EPOCH[313/1000] loss0.012-|Sample:9.66|
# EPOCH[314/1000] loss0.012-|Sample:9.76|
# EPOCH[315/1000] loss0.012-|Sample:9.61|
# EPOCH[316/1000] loss0.012-|Sample:9.80|
# EPOCH[317/1000] loss0.012-|Sample:9.41|
# EPOCH[318/1000] loss0.012-|Sample:8.97|
# EPOCH[319/1000] loss0.012-|Sample:9.50|
# EPOCH[320/1000] loss0.012-|Sample:9.65|
# [TEST]
# {'precision': array([0.05381305]), 'recall': array([0.17709647]), 'ndcg': array([0.15060088])}
# EPOCH[321/1000] loss0.012-|Sample:9.49|
# EPOCH[322/1000] loss0.012-|Sample:9.63|
# EPOCH[323/1000] loss0.012-|Sample:9.65|
# EPOCH[324/1000] loss0.012-|Sample:9.21|
# EPOCH[325/1000] loss0.012-|Sample:9.49|
# EPOCH[326/1000] loss0.012-|Sample:9.71|
# EPOCH[327/1000] loss0.012-|Sample:9.62|
# EPOCH[328/1000] loss0.012-|Sample:9.67|
# EPOCH[329/1000] loss0.012-|Sample:9.60|
# EPOCH[330/1000] loss0.012-|Sample:9.53|
# [TEST]
# {'precision': array([0.05408433]), 'recall': array([0.17791161]), 'ndcg': array([0.15087958])}
# EPOCH[331/1000] loss0.012-|Sample:9.42|
# EPOCH[332/1000] loss0.012-|Sample:9.55|
# EPOCH[333/1000] loss0.012-|Sample:9.71|
# EPOCH[334/1000] loss0.012-|Sample:9.64|
# EPOCH[335/1000] loss0.012-|Sample:9.55|
# EPOCH[336/1000] loss0.012-|Sample:9.70|
# EPOCH[337/1000] loss0.012-|Sample:9.66|
# EPOCH[338/1000] loss0.012-|Sample:9.47|
# EPOCH[339/1000] loss0.012-|Sample:9.51|
# EPOCH[340/1000] loss0.012-|Sample:9.17|
# [TEST]
# {'precision': array([0.05410108]), 'recall': array([0.17788504]), 'ndcg': array([0.15127244])}
# EPOCH[341/1000] loss0.012-|Sample:9.74|
# EPOCH[342/1000] loss0.012-|Sample:9.58|
# EPOCH[343/1000] loss0.012-|Sample:9.58|
# EPOCH[344/1000] loss0.012-|Sample:9.72|
# EPOCH[345/1000] loss0.012-|Sample:9.68|
# EPOCH[346/1000] loss0.012-|Sample:9.52|
# EPOCH[347/1000] loss0.012-|Sample:9.60|
# EPOCH[348/1000] loss0.012-|Sample:9.85|
# EPOCH[349/1000] loss0.012-|Sample:9.46|
# EPOCH[350/1000] loss0.012-|Sample:9.57|
# [TEST]
# {'precision': array([0.05429366]), 'recall': array([0.17857514]), 'ndcg': array([0.15170235])}
# EPOCH[351/1000] loss0.012-|Sample:9.32|
# EPOCH[352/1000] loss0.012-|Sample:9.72|
# EPOCH[353/1000] loss0.012-|Sample:9.62|
# EPOCH[354/1000] loss0.012-|Sample:9.74|
# EPOCH[355/1000] loss0.012-|Sample:9.50|
# EPOCH[356/1000] loss0.012-|Sample:9.64|
# EPOCH[357/1000] loss0.012-|Sample:9.56|
# EPOCH[358/1000] loss0.012-|Sample:9.37|
# EPOCH[359/1000] loss0.012-|Sample:8.95|
# EPOCH[360/1000] loss0.012-|Sample:9.64|
# [TEST]
# {'precision': array([0.05422835]), 'recall': array([0.17802112]), 'ndcg': array([0.15132022])}
# EPOCH[361/1000] loss0.012-|Sample:9.15|
# EPOCH[362/1000] loss0.012-|Sample:9.63|
# EPOCH[363/1000] loss0.012-|Sample:9.70|
# EPOCH[364/1000] loss0.012-|Sample:9.73|
# EPOCH[365/1000] loss0.012-|Sample:9.59|
# EPOCH[366/1000] loss0.012-|Sample:9.17|
# EPOCH[367/1000] loss0.012-|Sample:9.59|
# EPOCH[368/1000] loss0.012-|Sample:9.81|
# EPOCH[369/1000] loss0.012-|Sample:9.07|
# EPOCH[370/1000] loss0.012-|Sample:9.55|
# [TEST]
# {'precision': array([0.05433552]), 'recall': array([0.17834419]), 'ndcg': array([0.15154476])}
# EPOCH[371/1000] loss0.012-|Sample:9.44|
# EPOCH[372/1000] loss0.012-|Sample:9.67|
# EPOCH[373/1000] loss0.012-|Sample:9.65|
# EPOCH[374/1000] loss0.012-|Sample:9.68|
# EPOCH[375/1000] loss0.012-|Sample:9.36|
# EPOCH[376/1000] loss0.012-|Sample:9.71|
# EPOCH[377/1000] loss0.012-|Sample:9.50|
# EPOCH[378/1000] loss0.012-|Sample:9.20|
# EPOCH[379/1000] loss0.012-|Sample:9.60|
# EPOCH[380/1000] loss0.012-|Sample:9.49|
# [TEST]
# {'precision': array([0.05451638]), 'recall': array([0.17925355]), 'ndcg': array([0.15199854])}
# EPOCH[381/1000] loss0.012-|Sample:9.74|
# EPOCH[382/1000] loss0.012-|Sample:9.59|
# EPOCH[383/1000] loss0.012-|Sample:9.54|
# EPOCH[384/1000] loss0.012-|Sample:9.72|
# EPOCH[385/1000] loss0.012-|Sample:9.41|
# EPOCH[386/1000] loss0.012-|Sample:9.68|
# EPOCH[387/1000] loss0.012-|Sample:9.45|
# EPOCH[388/1000] loss0.012-|Sample:9.76|
